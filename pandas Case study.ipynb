# %% [markdown]
# PANDAS CASE STUDY : FIFA WORLD CUP DATASET

# %%
# install libraries (if not installed already)
# !pip install pandas
# !pip install numpy

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
# load the dataset
worldcup_df = pd.read_csv("world_cup_matches.csv")

# %%
worldcup_df
# Out:
#       ID  Year        Date           Stage      Home Team  Home Goals  \
# 0      1  1930  1930-07-13     Group stage         France           4
# 1      2  1930  1930-07-13     Group stage  United States           3
# 2      3  1930  1930-07-14     Group stage     Yugoslavia           2
# 3      4  1930  1930-07-14     Group stage        Romania           3
# 4      5  1930  1930-07-15     Group stage      Argentina           1
# ..   ...   ...         ...             ...            ...         ...
# 895  896  2018  2018-07-07  Quarter-finals         Russia           2
# 896  897  2018  2018-07-10     Semi-finals         France           1
# 897  898  2018  2018-07-11     Semi-finals        Croatia           2
# 898  899  2018  2018-07-14     Third place        Belgium           2
# 899  900  2018  2018-07-15           Final         France           4
#
#      Away Goals Away Team                    Win Conditions  Host Team
# ...

# %%
# make a copy
df = worldcup_df.copy()

# %% [markdown]
# ## EXPLORATION

# %%
# view first rows of the dataset
df.head()
# Out:
#    ID  Year        Date        Stage      Home Team  Home Goals  Away Goals  \
# 0   1  1930  1930-07-13  Group stage         France           4           1
# 1   2  1930  1930-07-13  Group stage  United States           3           0
# 2   3  1930  1930-07-14  Group stage     Yugoslavia           2           1
# 3   4  1930  1930-07-14  Group stage        Romania           3           1
# 4   5  1930  1930-07-15  Group stage      Argentina           1           0
#
#   Away Team Win Conditions  Host Team
# 0    Mexico            NaN      False
# 1   Belgium            NaN      False
# 2    Brazil            NaN      False
# 3      Peru            NaN      False
# 4    France            NaN      False

# %%
#view last few rows of the dataset
df.tail()
# Out:
#       ID  Year        Date           Stage Home Team  Home Goals  Away Goals  \
# 895  896  2018  2018-07-07  Quarter-finals    Russia           2           2
# 896  897  2018  2018-07-10     Semi-finals    France           1           0
# 897  898  2018  2018-07-11     Semi-finals   Croatia           2           1
# 898  899  2018  2018-07-14     Third place   Belgium           2           0
# 899  900  2018  2018-07-15           Final    France           4           2
#
#     Away Team                    Win Conditions  Host Team
# 895   Croatia  Croatia win on penalties (3 - 4)       True
# 896   Belgium                               NaN      False
# 897   England                        Extra time      False
# 898   England                               NaN      False
# 899   Croatia                               NaN      False

# %%
# how many rows are in our dataset
df.shape
# Out:
# (900, 10)

# %%
#structure of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              900 non-null    int64
#  1   Year            900 non-null    int64
#  2   Date            900 non-null    object
#  3   Stage           900 non-null    object
#  4   Home Team       900 non-null    object
#  5   Home Goals      900 non-null    int64
#  6   Away Goals      900 non-null    int64
#  7   Away Team       900 non-null    object
#  8   Win Conditions  62 non-null     object
#  9   Host Team       900 non-null    bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 64.3+ KB

# %%
#check for null values
df.isnull().sum()
# Out:
# ID                  0
# Year                0
# Date                0
# Stage               0
# Home Team           0
# Home Goals          0
# Away Goals          0
# Away Team           0
# Win Conditions    838
# Host Team           0
# dtype: int64

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#check data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              900 non-null    int64
#  1   Year            900 non-null    int64
#  2   Date            900 non-null    object
#  3   Stage           900 non-null    object
#  4   Home Team       900 non-null    object
#  5   Home Goals      900 non-null    int64
#  6   Away Goals      900 non-null    int64
#  7   Away Team       900 non-null    object
#  8   Win Conditions  62 non-null     object
#  9   Host Team       900 non-null    bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 64.3+ KB

# %%
#check for outliers
## Outliers are values that are greater or less than 2 standard deviation above/below the mean
df.describe()
# Out:
#                ID         Year  Home Goals  Away Goals
# count  900.000000   900.000000  900.000000  900.000000
# mean   450.500000  1986.915556    1.792222    1.038889
# std    259.951919    23.150270    1.593279    1.081567
# min      1.000000  1930.000000    0.000000    0.000000
# 25%    225.750000  1970.000000    1.000000    0.000000
# 50%    450.500000  1990.000000    2.000000    1.000000
# 75%    675.250000  2006.000000    3.000000    2.000000
# max    900.000000  2018.000000   10.000000    7.000000

# %%
# latest tournament year
df['Year'].max()
# Out:
# 2018

# %%
# Earliest tournament year
df['Year'].min()
# Out:
# 1930

# %%
df.columns
# Out:
# Index(['ID', 'Year', 'Date', 'Stage', 'Home Team', 'Home Goals', 'Away Goals',
#        'Away Team', 'Win Conditions', 'Host Team'],
#       dtype='object')

# %% [markdown]
# Outliers: values that are above or below 2 SD from the mean
#
#
# Isuues
#
# 1. win conditions has null values
# 2. date column: wrong data types
# 3. outliers in home and away goals
# 4. unstandardized column names

# %% [markdown]
# Data Cleaning

# %%
#Convert column to types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              900 non-null    int64
#  1   Year            900 non-null    int64
#  2   Date            900 non-null    object
#  3   Stage           900 non-null    object
#  4   Home Team       900 non-null    object
#  5   Home Goals      900 non-null    int64
#  6   Away Goals      900 non-null    int64
#  7   Away Team       900 non-null    object
#  8   Win Conditions  62 non-null     object
#  9   Host Team       900 non-null    bool
# dtypes: bool(1), int64(4), object(5)
# memory usage: 64.3+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'], format= '%Y-%m-%d', errors='raise')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              900 non-null    int64
#  1   Year            900 non-null    int64
#  2   Date            900 non-null    datetime64[ns]
#  3   Stage           900 non-null    object
#  4   Home Team       900 non-null    object
#  5   Home Goals      900 non-null    int64
#  6   Away Goals      900 non-null    int64
#  7   Away Team       900 non-null    object
#  8   Win Conditions  62 non-null     object
#  9   Host Team       900 non-null    bool
# dtypes: bool(1), datetime64[ns](1), int64(4), object(4)
# memory usage: 64.3+ KB

# %%
# How to change data type to float/int/boolean using astype method
df['Away Goals'].astype('int')
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 895    2
# 896    0
# 897    1
# 898    0
# 899    2
# Name: Away Goals, Length: 900, dtype: int32

# %%
## change/clean column names
df.columns
# Out:
# Index(['ID', 'Year', 'Date', 'Stage', 'Home Team', 'Home Goals', 'Away Goals',
#        'Away Team', 'Win Conditions', 'Host Team'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()

# %%
df.columns  = df.columns.str.replace("      ", " ")

# %%
df.columns
# Out:
# Index(['id', 'year', 'date', 'stage', 'home  team', 'home  goals',
#        'away  goals', 'away  team', 'win  conditions', 'host  team'],
#       dtype='object')

# %%
df.columns  = df.columns.str.replace(" ","_")

# %%
df.columns
# Out:
# Index(['id', 'year', 'date', 'stage', 'home__team', 'home__goals',
#        'away__goals', 'away__team', 'win__conditions', 'host__team'],
#       dtype='object')

# %%
df.head()
# Out:
#    id  year       date        stage     home__team  home__goals  away__goals  \
# 0   1  1930 1930-07-13  Group stage         France            4            1
# 1   2  1930 1930-07-13  Group stage  United States            3            0
# 2   3  1930 1930-07-14  Group stage     Yugoslavia            2            1
# 3   4  1930 1930-07-14  Group stage        Romania            3            1
# 4   5  1930 1930-07-15  Group stage      Argentina            1            0
#
#   away__team win__conditions  host__team
# 0     Mexico             NaN       False
# 1    Belgium             NaN       False
# 2     Brazil             NaN       False
# 3       Peru             NaN       False
# 4     France             NaN       False

# %%
df.rename(columns={'date': 'match_date', 'away__goals': 'ag', 'home__goals': 'hg'}, inplace =True)

# %%
df
# Out:
#       id  year match_date           stage     home__team  hg  ag away__team  \
# 0      1  1930 1930-07-13     Group stage         France   4   1     Mexico
# 1      2  1930 1930-07-13     Group stage  United States   3   0    Belgium
# 2      3  1930 1930-07-14     Group stage     Yugoslavia   2   1     Brazil
# 3      4  1930 1930-07-14     Group stage        Romania   3   1       Peru
# 4      5  1930 1930-07-15     Group stage      Argentina   1   0     France
# ..   ...   ...        ...             ...            ...  ..  ..        ...
# 895  896  2018 2018-07-07  Quarter-finals         Russia   2   2    Croatia
# 896  897  2018 2018-07-10     Semi-finals         France   1   0    Belgium
# 897  898  2018 2018-07-11     Semi-finals        Croatia   2   1    England
# 898  899  2018 2018-07-14     Third place        Belgium   2   0    England
# 899  900  2018 2018-07-15           Final         France   4   2    Croatia
#
#                       win__conditions  host__team
# ...

# %%
# missing values
df.isnull().sum()
# Out:
# id                   0
# year                 0
# match_date           0
# stage                0
# home__team           0
# hg                   0
# ag                   0
# away__team           0
# win__conditions    838
# host__team           0
# dtype: int64

# %% [markdown]
# Handling Missing values
# 1. dropping missing values
# 2. imputation
# . simple imputation: statistical imputation(using mean,mode,median); backfill and forwardfill (mainly for time series data)
# . advanced imputation: using data science models
#
# forward fill: Forward fill propagates the last known valid value forward to fill missing values. This is useful when we assume that the last observed values should remain valid until a new valid value appears.

# %%
df
# Out:
#       id  year match_date           stage     home__team  hg  ag away__team  \
# 0      1  1930 1930-07-13     Group stage         France   4   1     Mexico
# 1      2  1930 1930-07-13     Group stage  United States   3   0    Belgium
# 2      3  1930 1930-07-14     Group stage     Yugoslavia   2   1     Brazil
# 3      4  1930 1930-07-14     Group stage        Romania   3   1       Peru
# 4      5  1930 1930-07-15     Group stage      Argentina   1   0     France
# ..   ...   ...        ...             ...            ...  ..  ..        ...
# 895  896  2018 2018-07-07  Quarter-finals         Russia   2   2    Croatia
# 896  897  2018 2018-07-10     Semi-finals         France   1   0    Belgium
# 897  898  2018 2018-07-11     Semi-finals        Croatia   2   1    England
# 898  899  2018 2018-07-14     Third place        Belgium   2   0    England
# 899  900  2018 2018-07-15           Final         France   4   2    Croatia
#
#                       win__conditions  host__team
# ...

# %%
#.dropna/.fillna

# %%
df ['win__conditions'] = df ['win__conditions'].fillna("Normal Time")

# %%
df.isnull().sum()
# Out:
# id                 0
# year               0
# match_date         0
# stage              0
# home__team         0
# hg                 0
# ag                 0
# away__team         0
# win__conditions    0
# host__team         0
# dtype: int64

# %%
# filling NA in win_condition with 'normal time'

# %% [markdown]
# DATA TRANSFORMATION

# %%
cleaned_df = df.copy()

# %%
## Add a new column for total goals
df['total_goals'] = df ['hg'] + df['ag']

# %%
df
# Out:
#       id  year match_date           stage     home__team  hg  ag away__team  \
# 0      1  1930 1930-07-13     Group stage         France   4   1     Mexico
# 1      2  1930 1930-07-13     Group stage  United States   3   0    Belgium
# 2      3  1930 1930-07-14     Group stage     Yugoslavia   2   1     Brazil
# 3      4  1930 1930-07-14     Group stage        Romania   3   1       Peru
# 4      5  1930 1930-07-15     Group stage      Argentina   1   0     France
# ..   ...   ...        ...             ...            ...  ..  ..        ...
# 895  896  2018 2018-07-07  Quarter-finals         Russia   2   2    Croatia
# 896  897  2018 2018-07-10     Semi-finals         France   1   0    Belgium
# 897  898  2018 2018-07-11     Semi-finals        Croatia   2   1    England
# 898  899  2018 2018-07-14     Third place        Belgium   2   0    England
# 899  900  2018 2018-07-15           Final         France   4   2    Croatia
#
# ...

# %%
## add a column for score category (based on a condition)
## method 1: using numpy function

# %%
df['score_category'] = np.where(df['total_goals']>2,'High scoring', 'Low scoring')

# %%
df
# Out:
#       id  year match_date           stage     home__team  hg  ag away__team  \
# 0      1  1930 1930-07-13     Group stage         France   4   1     Mexico
# 1      2  1930 1930-07-13     Group stage  United States   3   0    Belgium
# 2      3  1930 1930-07-14     Group stage     Yugoslavia   2   1     Brazil
# 3      4  1930 1930-07-14     Group stage        Romania   3   1       Peru
# 4      5  1930 1930-07-15     Group stage      Argentina   1   0     France
# ..   ...   ...        ...             ...            ...  ..  ..        ...
# 895  896  2018 2018-07-07  Quarter-finals         Russia   2   2    Croatia
# 896  897  2018 2018-07-10     Semi-finals         France   1   0    Belgium
# 897  898  2018 2018-07-11     Semi-finals        Croatia   2   1    England
# 898  899  2018 2018-07-14     Third place        Belgium   2   0    England
# 899  900  2018 2018-07-15           Final         France   4   2    Croatia
#
# ...

# %%
## method 2: using a custom or lambda function

# %%
## using custom function
def score_category (X):
    if X > 2:
        return 'High Scoring'
    else:
        return 'Low Scoring'

# %%
df['score_category2'] = df['total_goals'].apply(score_category)

# %%
df
# Out:
#       id  year match_date           stage     home__team  hg  ag away__team  \
# 0      1  1930 1930-07-13     Group stage         France   4   1     Mexico
# 1      2  1930 1930-07-13     Group stage  United States   3   0    Belgium
# 2      3  1930 1930-07-14     Group stage     Yugoslavia   2   1     Brazil
# 3      4  1930 1930-07-14     Group stage        Romania   3   1       Peru
# 4      5  1930 1930-07-15     Group stage      Argentina   1   0     France
# ..   ...   ...        ...             ...            ...  ..  ..        ...
# 895  896  2018 2018-07-07  Quarter-finals         Russia   2   2    Croatia
# 896  897  2018 2018-07-10     Semi-finals         France   1   0    Belgium
# 897  898  2018 2018-07-11     Semi-finals        Croatia   2   1    England
# 898  899  2018 2018-07-14     Third place        Belgium   2   0    England
# 899  900  2018 2018-07-15           Final         France   4   2    Croatia
#
# ...

# %%
#using a Lambda function
df['score_category3'] = df['total_goals'].apply(lambda X: 'High Scoring' if X>2 else 'Low Scoring')

# %%
df
# Out:
#       id  year match_date           stage     home__team  hg  ag away__team  \
# 0      1  1930 1930-07-13     Group stage         France   4   1     Mexico
# 1      2  1930 1930-07-13     Group stage  United States   3   0    Belgium
# 2      3  1930 1930-07-14     Group stage     Yugoslavia   2   1     Brazil
# 3      4  1930 1930-07-14     Group stage        Romania   3   1       Peru
# 4      5  1930 1930-07-15     Group stage      Argentina   1   0     France
# ..   ...   ...        ...             ...            ...  ..  ..        ...
# 895  896  2018 2018-07-07  Quarter-finals         Russia   2   2    Croatia
# 896  897  2018 2018-07-10     Semi-finals         France   1   0    Belgium
# 897  898  2018 2018-07-11     Semi-finals        Croatia   2   1    England
# 898  899  2018 2018-07-14     Third place        Belgium   2   0    England
# 899  900  2018 2018-07-15           Final         France   4   2    Croatia
#
# ...

# %%
## filtering dataframes
## group stage game
condition = df['stage'] == 'Group stage'
df[condition]
# Out:
#       id  year match_date        stage     home__team  hg  ag  away__team  \
# 0      1  1930 1930-07-13  Group stage         France   4   1      Mexico
# 1      2  1930 1930-07-13  Group stage  United States   3   0     Belgium
# 2      3  1930 1930-07-14  Group stage     Yugoslavia   2   1      Brazil
# 3      4  1930 1930-07-14  Group stage        Romania   3   1        Peru
# 4      5  1930 1930-07-15  Group stage      Argentina   1   0      France
# ..   ...   ...        ...          ...            ...  ..  ..         ...
# 879  880  2018 2018-06-27  Group stage    Switzerland   2   2  Costa Rica
# 880  881  2018 2018-06-28  Group stage          Japan   0   1      Poland
# 881  882  2018 2018-06-28  Group stage        Senegal   0   1    Colombia
# 882  883  2018 2018-06-28  Group stage         Panama   1   2     Tunisia
# 883  884  2018 2018-06-28  Group stage        England   0   1     Belgium
#
#     win__conditions  host__team  total_goals score_category score_category2  \
# ...

# %%
condition = df['year'] == 2010
df[condition]
# Out:
#       id  year match_date           stage    home__team  hg  ag  \
# 708  709  2010 2010-06-11     Group stage  South Africa   1   1
# 709  710  2010 2010-06-11     Group stage       Uruguay   0   0
# 710  711  2010 2010-06-12     Group stage   South Korea   2   0
# 711  712  2010 2010-06-12     Group stage     Argentina   1   0
# 712  713  2010 2010-06-12     Group stage       England   1   1
# ..   ...   ...        ...             ...           ...  ..  ..
# 767  768  2010 2010-07-03  Quarter-finals      Paraguay   0   1
# 768  769  2010 2010-07-06     Semi-finals       Uruguay   2   3
# 769  770  2010 2010-07-07     Semi-finals       Germany   0   1
# 770  771  2010 2010-07-10     Third place       Uruguay   2   3
# 771  772  2010 2010-07-11           Final   Netherlands   0   1
#
#         away__team win__conditions  host__team  total_goals score_category  \
# 708         Mexico     Normal Time        True            2    Low scoring
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               900 non-null    int64
#  1   year             900 non-null    int64
#  2   match_date       900 non-null    datetime64[ns]
#  3   stage            900 non-null    object
#  4   home__team       900 non-null    object
#  5   hg               900 non-null    int64
#  6   ag               900 non-null    int64
#  7   away__team       900 non-null    object
#  8   win__conditions  900 non-null    object
#  9   host__team       900 non-null    bool
#  10  total_goals      900 non-null    int64
#  11  score_category   900 non-null    object
#  12  score_category2  900 non-null    object
#  13  score_category3  900 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(5), object(7)
# memory usage: 92.4+ KB

# %%
## filtering with multiple conditions
condition1 = df['stage'] == 'Group stage'
condition2 =df ['year'] == 2010
condition3 = df['year'] == 1930
df[condition1 & (condition2 | condition3)]
# Out:
#       id  year match_date        stage     home__team  hg  ag   away__team  \
# 0      1  1930 1930-07-13  Group stage         France   4   1       Mexico
# 1      2  1930 1930-07-13  Group stage  United States   3   0      Belgium
# 2      3  1930 1930-07-14  Group stage     Yugoslavia   2   1       Brazil
# 3      4  1930 1930-07-14  Group stage        Romania   3   1         Peru
# 4      5  1930 1930-07-15  Group stage      Argentina   1   0       France
# ..   ...   ...        ...          ...            ...  ..  ..          ...
# 751  752  2010 2010-06-24  Group stage       Cameroon   1   2  Netherlands
# 752  753  2010 2010-06-25  Group stage       Portugal   0   0       Brazil
# 753  754  2010 2010-06-25  Group stage    North Korea   0   3  Ivory Coast
# 754  755  2010 2010-06-25  Group stage          Chile   1   2        Spain
# 755  756  2010 2010-06-25  Group stage    Switzerland   0   0     Honduras
#
# ...

# %% [markdown]
# GENERATE INSIGHTS

# %%
#1. which team played the most fifa world cup matches
# we concatenate (combine) the home and away teams and do a value counts

# %%
pd.concat([df['home__team'],df['away__team']]).value_counts()
# Out:
# Brazil       109
# Germany      109
# Italy         83
# Argentina     81
# England       69
#             ...
# China          3
# Cuba           3
# Jamaica        3
# Kuwait         3
# Indonesia      1
# Name: count, Length: 81, dtype: int64

# %%
# highest scoring tournaments
# group by year
#aggregate (sum of total goals)
#sort descending
#filter top 5
yearly_goals = df.groupby('year')['total_goals'].sum().sort_values(ascending=False)
yearly_goals
# Out:
# year
# 2014    171
# 1998    171
# 2018    169
# 2002    161
# 2006    147
# 1982    146
# 2010    145
# 1994    141
# 1954    140
# 1986    132
# 1958    126
# 1990    115
# 1978    102
# 1974     97
# 1970     95
# 1966     89
# 1962     89
# 1950     88
# 1938     84
# 1934     70
# 1930     70
# Name: total_goals, dtype: int64

# %%
top5_years = yearly_goals[:5]
top5_years
# Out:
# year
# 2014    171
# 1998    171
# 2018    169
# 2002    161
# 2006    147
# Name: total_goals, dtype: int64

# %%
top5_years.index
# Out:
# Index([2014, 1998, 2018, 2002, 2006], dtype='int64', name='year')

# %%
## which countries hosted the world cup in these years
#filter for the top scoring years
#look for the host team is True
#drop duplicates

# %%
condition1 = df['year'].isin(top5_years.index)
condition2 = df['host__team'] == True
df[condition1 & condition2][['year', 'home__team','host__team' ]].drop_duplicates()
# Out:
#      year   home__team  host__team
# 522  1998       France        True
# 592  2002        Japan        True
# 593  2002  South Korea        True
# 644  2006      Germany        True
# 772  2014       Brazil        True
# 836  2018       Russia        True

# %%
#3 How many goals has each team scored in the fifa world cup? which team has scored 
# approach is to get  all the gosls scored by each country as home team;
# get all goals scored by each country as away team;
#concatenate (combine) the two arrays from step 1 and 2
# then get the total goals for each country

# %%
# total goals as home and away
df.groupby('home__team') ['hg'].sum().reset_index()
home_goals_df = df.groupby('home__team') ['hg'].sum().reset_index()
aways_goals_df = df.groupby('away__team') ['ag'].sum().reset_index()

# %%
aways_goals_df
# Out:
#               away__team  ag
# 0                Algeria   8
# 1                 Angola   1
# 2              Argentina  27
# 3              Australia   6
# 4                Austria  19
# ..                   ...  ..
# 76  United Arab Emirates   2
# 77         United States  18
# 78               Uruguay  22
# 79                 Wales   2
# 80            Yugoslavia  18
#
# [81 rows x 2 columns]

# %%
home_goals_df
# Out:
#               home__team   hg
# 0                Algeria    5
# 1                 Angola    0
# 2              Argentina  110
# 3              Australia    7
# 4                Austria   24
# ..                   ...  ...
# 72  United Arab Emirates    0
# 73         United States   19
# 74               Uruguay   65
# 75                 Wales    2
# 76            Yugoslavia   42
#
# [77 rows x 2 columns]

# %%
#combine the two arrays
total_goals_df = pd.concat([home_goals_df.rename(columns={'home__team':'team','hg':'goals'}),
           aways_goals_df.rename(columns={'away__team': 'team','ag':'goals'})],ignore_index=True)

# %%
total_goals_df.groupby('team')['goals'].sum().sort_values(ascending=False)
# Out:
# team
# Brazil                 229
# Germany                226
# Argentina              137
# Italy                  128
# France                 120
#                       ...
# Canada                   0
# Trinidad and Tobago      0
# China                    0
# DR Congo                 0
# Indonesia                0
# Name: goals, Length: 81, dtype: int64
